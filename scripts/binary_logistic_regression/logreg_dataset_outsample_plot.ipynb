# %% [markdown]
# # Predicted probabilities of out-of-sample datasets
#
# NOTE: the probabilities shown below are based on multiple classifiers! Each dataset is predicted using a classifier not trained on this dataset or any datasets from the sampe family (see [here](core/dataset_categories.py)) using [logreg_dataset_outsample.py](logreg_dataset_outsample.py). See Brunner and Sippel (2023) for more information on the methodology.
#
# NOTE: all testsamples are from a different period (2005-2014) than the training period (1984-2001) in addition!

# %%
import os
import sys
import pickle
sys.path.append('../')

import core.plot_functions as pf

# %%
# probabilities by dataset
pp_dataset = pickle.load(open(os.path.join('../../data/trained_classifiers', 'logreg_dataset_outsample_lm_gm.sav'), 'rb'))

# %%
pf.plot_probabilities_model(pp_dataset, show_legend=True)
# Out:
# <AxesSubplot: xlabel='Probability to be an observation', ylabel='Models'>
